# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading data
car=pd.read_csv(r"C:\Users\SriSudha Lingala\Documents\Engage-2022\cars_engage_2022.csv")
car
# Out:
#       Unnamed: 0        Make      Model        Variant      Price  \
# 0              0        Tata  Nano Genx             Xt   2,92,667
# 1              1        Tata  Nano Genx             Xe   2,36,447
# 2              2        Tata  Nano Genx        Emax Xm   2,96,661
# 3              3        Tata  Nano Genx            Xta   3,34,768
# 4              4        Tata  Nano Genx             Xm   2,72,223
# ...          ...         ...        ...            ...        ...
# 1271        1271       Honda       City   Vx Mt Diesel  13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel  14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol  14,31,000
# 1274        1274       Honda       City   V Cvt Petrol  12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At  68,62,560
#
#       Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0            624.0        2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
car['Make'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
(car['Make'].value_counts().head(10) / len(car)).plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Make'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Model'].value_counts().head(20).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Model'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Model'].value_counts().tail().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Fuel_Type'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Cylinders'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Valves_Per_Cylinder'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Drivetrain'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Cylinder_Configuration'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Emission_Norm'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Engine_Location'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Fuel_System'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Fuel_Tank_Capacity'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Body_Type'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Doors'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Highway_Mileage'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['ARAI_Certified_Mileage'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['ARAI_Certified_Mileage_for_CNG'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Kerb_Weight'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Gears'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Ground_Clearance'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Front_Brakes'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Rear_Brakes'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Front_Suspension'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Rear_Suspension'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Front_Track'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Rear_Track'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Front_Tyre_&_Rim'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Rear_Tyre_&_Rim'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Power_Steering'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Power_Windows'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Power_Seats'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Keyless_Entry'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Power'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Torque'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Odometer'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Speedometer'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Tachometer'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Tripmeter'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Seating_Capacity'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Seats_Material'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Type'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Wheelbase'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Wheels_Size'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Start_/_Stop_Button'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['12v_Power_Outlet'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Audiosystem'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Aux-in_Compatibility'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Average_Fuel_Consumption'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Basic_Warranty'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Boot_Space'].value_counts().head(30).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['CD_/_MP3_/_DVD_Player'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Clock'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Child_Safety_Locks'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Cup_Holders'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Central_Locking'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Door_Pockets'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Fuel-lid_Opener'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Fuel_Gauge'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Handbrake'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Instrument_Console'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Sun_Visor'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Auto-Diing_Rear-View_Mirror'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Key_Off_Reminder'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car['Infotainment_Screen'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
x=car['Model'].head(30)
y=car['Price'].head(30)
plt.xlabel('Model',fontsize=18)
plt.ylabel('Price',fontsize=16)
plt.bar(x,y)
plt.show()
