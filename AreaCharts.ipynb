# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading data
car=pd.read_csv(r"C:\Users\SriSudha Lingala\Documents\Engage-2022\cars_engage_2022.csv")
car
# Out:
#       Unnamed: 0        Make      Model        Variant      Price  \
# 0              0        Tata  Nano Genx             Xt   2,92,667
# 1              1        Tata  Nano Genx             Xe   2,36,447
# 2              2        Tata  Nano Genx        Emax Xm   2,96,661
# 3              3        Tata  Nano Genx            Xta   3,34,768
# 4              4        Tata  Nano Genx             Xm   2,72,223
# ...          ...         ...        ...            ...        ...
# 1271        1271       Honda       City   Vx Mt Diesel  13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel  14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol  14,31,000
# 1274        1274       Honda       City   V Cvt Petrol  12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At  68,62,560
#
#       Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0            624.0        2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
car['Price'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Displacement'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Make'].value_counts().head().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Model'].value_counts().head().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Variant'].value_counts().head().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Cylinders'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Valves_Per_Cylinder'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
p=car['Price']
l1=car['Height']
l2=car['Width']
l3=car['Length']

# %%
plt.stackplot(p,l1,l2,l3,labels=['Height','Width','Length'])
plt.legend()

# %%
plt.stackplot(car['Cylinders'],car['Valves_Per_Cylinder'])
plt.legend(['Valves_Per_Cylinder'])

# %%
car['City_Mileage'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Highway_Mileage'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Ground_Clearance'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Speedometer'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Odometer'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Tripmeter'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Tachometer'].value_counts().head().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Wheelbase'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
car['Infotainment_Screen'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>
